# %% [markdown]
# # <a id="top"></a>Autoencoding Edward Hopper:<br>Using deep learning to recommend art
#
# [Larry Finer](mailto:lfiner@gmail.com)
# March 2019
#
# The goal of this project was to build a model that would take an image of an artwork and compare it visually to a corpus of more than 100,000 artworks from museums and other sources in order to find works that are similar visually. The main steps in the project were:
#
# 1. <b>Download artwork images and metadata from multiple sites</b> (this file)
# 2. Combine metadata into a single pandas dataframe
# 3. Develop a convolutional neural network autoencoder model that adequately reproduces the images
# 4. Extract the narrowest encoded layer and use it to encode the entire corpus as well as a test image; then compare the test image to the entire corpus using a cosine distance measure to find the nearest images
#
# <hr>
#
# ## 1b. Download Artspace images
#
# This file downloads Artspace's entire online collection of approximately 16,000 images. Metadata for each artwork, including artist, title, date, and medium, were already downloaded in [a previous project I did](https://github.com/lfiner/predicting-art-prices).
#
# ### Sections
# 1b1. [Imports and setup](#1b1)
# 1b2. [Download images](#1b2)

# %% [markdown]
# ### <a id="1b1"></a>1b1. Imports and setup

# %%
import pandas as pd
import random
import time
import pickle
import urllib.request
import requests
from fake_useragent import UserAgent
from itertools import islice

# %%
# Establish an instance of the UserAgent for randomizing where my web requests come from
ua = UserAgent()
user_agent = {'User-agent': ua.random}

# %% [markdown]
# ### <a id="1b2"></a>1b2. Download images

# %%
# Load the metadata file created in the "Predicting art prices" project
df = pickle.load(open('./data/artspace/Artists and artworks dataframe.pickle', 'rb'))

# %%
df.shape
# Out:
# (15774, 72)

# %%
df.columns
# Out:
# Index(['artist', 'artwork_id', 'artwork_url', 'authentication', 'edition_size',
#        'fame_cat', 'height', 'image_url', 'location', 'medium',
#        'physical_description', 'price', 'styles', 'tags', 'title', 'width',
#        'year_created', 'book', 'decorative-arts', 'mixed-media', 'new-media',
#        'no-medium', 'painting', 'photograph', 'print', 'sculpture',
#        'work-on-paper', 'unique', 'edition_size2', 'log_edition',
#        'edition_grp', 'ed-1', 'ed-101-more', 'ed-11-30', 'ed-2-10', 'ed-31-50',
#        'ed-51-100', 'signed', 'log_price', 'area', 'log_area', 'created_cat',
#        'cr-1960s-70s', 'cr-1980s-90s', 'cr-2000s', 'cr-2010s', 'cr-pre-1960',
#        'blue-chip', 'established', 'non-strategic', 'rising-star',
#        'up-and-coming', 'name_lf', 'id', 'name_pretty', 'birth_year',
#        'hometown', 'lives_in', 'degrees', 'degrees_n', 'genres', 'museums',
#        'museums_n', 'galleries', 'galleries_n', 'name_last', 'artist_death',
#        'dead', 'degrees_cat', 'galleries_cat', 'museums_cat', 'log_museums_n'],
#       dtype='object')

# %%
# Convert ID to integer
df.artwork_id = df.artwork_id.astype(int)

# %%
df.reset_index(drop=True)
# Out:
#                     artist  artwork_id  \
# 0         lola-soloveychik       35537
# 1         lola-soloveychik       35538
# 2           mimmo_paladino       53265
# 3           mimmo_paladino       32803
# 4           mimmo_paladino       33077
# 5      jonathan-ryan-storm       53062
# 6      jonathan-ryan-storm       53068
# 7      jonathan-ryan-storm       53070
# 8      jonathan-ryan-storm       53075
# 9          thomas-hylander       16046
# 10         thomas-hylander       16047
# 11         thomas-hylander       16044
# 12             raymond-saa       57824
# 13             fanny-allie       40737
# 14             fanny-allie       40738
# 15             fanny-allie       40739
# 16             fanny-allie       40740
# 17             fanny-allie       40741
# 18             fanny-allie       40742
# 19             fanny-allie       40744
# 20             fanny-allie       40745
# 21             fanny-allie       40746
# 22             fanny-allie       40747
# 23             fanny-allie       40748
# 24             fanny-allie       40749
# 25             fanny-allie       40750
# 26             fanny-allie       40751
# 27             fanny-allie       40752
# 28             fanny-allie       39409
# 29             fanny-allie       39410
# ...                    ...         ...
# 15744      elisabeth-horan       38494
# 15745      elisabeth-horan       38495
# 15746      elisabeth-horan       38496
# 15747      elisabeth-horan       38497
# 15748      elisabeth-horan       38498
# 15749      elisabeth-horan       38499
# 15750      elisabeth-horan       38500
# 15751      elisabeth-horan       11504
# 15752      elisabeth-horan       12802
# 15753      elisabeth-horan       12803
# 15754        rachel-cabitt       49217
# 15755        rachel-cabitt       44718
# 15756        rachel-cabitt       39238
# 15757        rachel-cabitt       39297
# 15758        rachel-cabitt       39298
# 15759        rachel-cabitt       47876
# 15760       sigalit_landau         556
# 15761           greg-slick       47768
# 15762           greg-slick       47769
# 15763           greg-slick       47770
# 15764           greg-slick       47771
# 15765           greg-slick       47772
# 15766          laura_owens       46721
# 15767          laura_owens       14086
# 15768          laura_owens       12722
# 15769     harvey-littleton       40616
# 15770         clemens-wolf       30093
# 15771         clemens-wolf       44072
# 15772         clemens-wolf       44073
# 15773         clemens-wolf       44074
#
#                                              artwork_url  \
# 0      https://www.artspace.com/lola-soloveychik/the-...
# 1      https://www.artspace.com/lola-soloveychik/cali...
# 2      https://www.artspace.com/mimmo_paladino/horse-...
# 3      https://www.artspace.com/mimmo_paladino/gli-an...
# 4      https://www.artspace.com/mimmo_paladino/il-sog...
# 5       https://www.artspace.com/jonathan-ryan-storm/woo
# 6        https://www.artspace.com/jonathan-ryan-storm/ep
# 7      https://www.artspace.com/jonathan-ryan-storm/x...
# 8      https://www.artspace.com/jonathan-ryan-storm/s...
# 9      https://www.artspace.com/thomas-hylander/untitled
# 10     https://www.artspace.com/thomas-hylander/untit...
# 11     https://www.artspace.com/thomas-hylander/day-t...
# 12       https://www.artspace.com/raymond-saa/untitled-e
# 13     https://www.artspace.com/fanny-allie/the-astro...
# 14     https://www.artspace.com/fanny-allie/dancing-lady
# 15          https://www.artspace.com/fanny-allie/fur-man
# 16     https://www.artspace.com/fanny-allie/guard-tongue
# 17       https://www.artspace.com/fanny-allie/guard-wool
# 18     https://www.artspace.com/fanny-allie/man-strip...
# 19     https://www.artspace.com/fanny-allie/old-lady-...
# 20        https://www.artspace.com/fanny-allie/the-bride
# 21        https://www.artspace.com/fanny-allie/the-guard
# 22         https://www.artspace.com/fanny-allie/the-lady
# 23         https://www.artspace.com/fanny-allie/the-page
# 24     https://www.artspace.com/fanny-allie/the-shepherd
# 25     https://www.artspace.com/fanny-allie/the-wrestler
# 26     https://www.artspace.com/fanny-allie/woman-lea...
# 27     https://www.artspace.com/fanny-allie/woman-wit...
# 28         https://www.artspace.com/fanny-allie/4-clowns
# 29      https://www.artspace.com/fanny-allie/eg-protests
# ...                                                  ...
# 15744  https://www.artspace.com/elisabeth-horan/party...
# 15745  https://www.artspace.com/elisabeth-horan/dinne...
# 15746  https://www.artspace.com/elisabeth-horan/holy-...
# 15747   https://www.artspace.com/elisabeth-horan/gateway
# 15748  https://www.artspace.com/elisabeth-horan/still...
# 15749    https://www.artspace.com/elisabeth-horan/medium
# 15750    https://www.artspace.com/elisabeth-horan/seance
# 15751  https://www.artspace.com/elisabeth-horan/warm-...
# 15752   https://www.artspace.com/elisabeth-horan/yinyang
# 15753  https://www.artspace.com/elisabeth-horan/untit...
# 15754  https://www.artspace.com/rachel-cabitt/fifty-d...
# 15755  https://www.artspace.com/rachel-cabitt/the-gat...
# 15756       https://www.artspace.com/rachel-cabitt/babys
# 15757     https://www.artspace.com/rachel-cabitt/natalie
# 15758        https://www.artspace.com/rachel-cabitt/jake
# 15759     https://www.artspace.com/rachel-cabitt/glasses
# 15760       https://www.artspace.com/sigalit_landau/orla
# 15761        https://www.artspace.com/greg-slick/overlay
# 15762  https://www.artspace.com/greg-slick/untitled-1...
# 15763  https://www.artspace.com/greg-slick/untitled-4...
# 15764  https://www.artspace.com/greg-slick/untitled-6...
# 15765  https://www.artspace.com/greg-slick/untitled-8...
# 15766  https://www.artspace.com/laura_owens/untitled-...
# 15767    https://www.artspace.com/laura_owens/untitled-1
# 15768      https://www.artspace.com/laura_owens/untitled
# 15769  https://www.artspace.com/harvey-littleton/cyli...
# 15770  https://www.artspace.com/clemens-wolf/black-be...
# 15771  https://www.artspace.com/clemens-wolf/line-dra...
# 15772  https://www.artspace.com/clemens-wolf/line-dra...
# 15773  https://www.artspace.com/clemens-wolf/parachut...
#
#                                           authentication  edition_size  \
# 0                     Signed and numbered by the artist.          10.0
# 1                     Signed and numbered by the artist.          10.0
# 2                                                   None           NaN
# 3      This work is signed and dated by the artist in...          60.0
# 4      This work is signed and dated by the artist in...          60.0
# 5                          This work is signed on verso.           1.0
# 6                          This work is signed on verso.           1.0
# 7                          this work is signed on verso.           1.0
# 8                          This work is signed on verso.           1.0
# 9                                   This work is signed.           1.0
# 10                                  This work is signed.           1.0
# 11                                  This work is signed.           1.0
# 12     This work comes with a Certificate of Authenti...           1.0
# 13          This work is signed by the artist on bottom.           1.0
# 14          This work is signed by the artist on bottom.           1.0
# 15          This work is signed by the artist on bottom.           1.0
# 16          This work is signed by the artist on bottom.           1.0
# 17          This work is signed by the artist on bottom.           1.0
# 18          This work is signed by the artist on bottom.           1.0
# 19          This work is signed by the artist on bottom.           1.0
# 20          This work is signed by the artist on bottom.           1.0
# 21          This work is signed by the artist on bottom.           1.0
# 22          This work is signed by the artist on bottom.           1.0
# 23          This work is signed by the artist on bottom.           1.0
# 24          This work is signed by the artist on bottom.           1.0
# 25          This work is signed by the artist on bottom.           1.0
# 26          This work is signed by the artist on bottom.           1.0
# 27          This work is signed by the artist on bottom.           1.0
# 28       This work is initialed by the artist in pencil.           1.0
# 29           This work is signed by the artist on verso.           1.0
# ...                                                  ...           ...
# 15744        This work is signed by the artist on recto.           1.0
# 15745        This work is signed by the artist on recto.           1.0
# 15746        This work is signed by the artist on verso.           1.0
# 15747        This work is signed by the artist on verso.           1.0
# 15748        This work is signed by the artist on verso.           1.0
# 15749        This work is signed by the artist on verso.           1.0
# 15750        This work is signed by the artist on verso.           1.0
# 15751                      This work is signed on verso.           1.0
# 15752                      This work is signed on verso.           1.0
# 15753                      This work is signed on verso.           1.0
# 15754        This work is signed by the artist on verso.           3.0
# 15755        This work is signed by the artist on verso.           3.0
# 15756                      This work is signed on verso.           3.0
# 15757        This work is signed by the artist on verso.           3.0
# 15758        This work is signed by the artist on verso.           3.0
# 15759        This work is signed by the artist on verso.           3.0
# 15760  Signed and numbered by the artist and includes...          20.0
# 15761        This work is signed by the artist on verso.           1.0
# 15762        This work is signed by the artist on verso.           1.0
# 15763        This work is signed by the artist on verso.           1.0
# 15764        This work is signed by the artist on verso.           1.0
# 15765        This work is signed by the artist on verso.           1.0
# 15766          This works is signed, dated and numbered.          40.0
# 15767                               This work is signed.          20.0
# 15768                      This work is signed on verso.         100.0
# 15769  Incised signature and date by the artist (on b...           NaN
# 15770            This work is signed and dated on verso.           1.0
# 15771             The work is signed and dated on verso.           1.0
# 15772             The work is signed and dated on verso.           1.0
# 15773             The work is signed and dated on verso.           1.0
#
#        fame_cat    height                                          image_url  \
# 0           0.0  10.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 1           0.0   8.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 2           1.0  37.20465  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 3           1.0  32.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 4           1.0  32.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 5           0.0  15.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 6           0.0  12.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 7           0.0  11.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 8           0.0  35.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 9           1.0  13.77950  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 10          1.0   9.84250  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 11          1.0  33.46450  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 12          1.0  33.50000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 13          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 14          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 16          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 17          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 18          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 19          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 20          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 21          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 22          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 23          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 24          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 25          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 26          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 27          0.0       NaN  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 28          0.0  16.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 29          0.0   8.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# ...         ...       ...                                                ...
# 15744       0.0  15.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15745       0.0  16.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15746       0.0  11.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15747       0.0  10.50000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15748       0.0  11.50000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15749       0.0   6.50000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15750       0.0  19.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15751       0.0  28.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15752       0.0  30.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15753       0.0  22.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15754       0.0  20.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15755       0.0  20.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15756       0.0  24.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15757       0.0  24.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15758       0.0  24.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15759       0.0  20.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15760       3.0   9.00000  https://d5wt70d4gnm1t.cloudfront.net/media/sig...
# 15761       0.0  35.75000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15762       0.0  12.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15763       0.0  12.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15764       0.0  12.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15765       0.0  12.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15766       2.0  25.50000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15767       2.0  29.99994  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15768       2.0   7.50000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15769       0.0   7.00000  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15770       1.0  40.15740  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15771       1.0  16.92910  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15772       1.0  16.92910  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
# 15773       1.0  47.24400  https://d5wt70d4gnm1t.cloudfront.net/media/a-s...
#
#             location           medium  ... museums_n  \
# 0                          photograph  ...       0.0
# 1                          photograph  ...       0.0
# 2             London            print  ...       1.0
# 3      United States            print  ...       1.0
# 4      United States            print  ...       1.0
# 5           New York      mixed-media  ...       0.0
# 6           New York      mixed-media  ...       0.0
# 7           New York      mixed-media  ...       0.0
# 8           New York         painting  ...       0.0
# 9         Copenhagen        sculpture  ...       2.0
# 10        Copenhagen        sculpture  ...       2.0
# 11        Copenhagen         painting  ...       2.0
# 12          New York    work-on-paper  ...       0.0
# 13                    decorative-arts  ...       0.0
# 14                    decorative-arts  ...       0.0
# 15                    decorative-arts  ...       0.0
# 16                    decorative-arts  ...       0.0
# 17                    decorative-arts  ...       0.0
# 18                    decorative-arts  ...       0.0
# 19                    decorative-arts  ...       0.0
# 20                    decorative-arts  ...       0.0
# 21                    decorative-arts  ...       0.0
# 22                    decorative-arts  ...       0.0
# 23                    decorative-arts  ...       0.0
# 24                    decorative-arts  ...       0.0
# 25                    decorative-arts  ...       0.0
# 26                    decorative-arts  ...       0.0
# 27                    decorative-arts  ...       0.0
# 28                        mixed-media  ...       0.0
# 29                        mixed-media  ...       0.0
# ...              ...              ...  ...       ...
# 15744                      photograph  ...       0.0
# 15745                      photograph  ...       0.0
# 15746                   work-on-paper  ...       0.0
# 15747                   work-on-paper  ...       0.0
# 15748                   work-on-paper  ...       0.0
# 15749                   work-on-paper  ...       0.0
# 15750                   work-on-paper  ...       0.0
# 15751                   work-on-paper  ...       0.0
# 15752                   work-on-paper  ...       0.0
# 15753                   work-on-paper  ...       0.0
# 15754      Ridgewood       photograph  ...       0.0
# 15755      Ridgewood       photograph  ...       0.0
# 15756      Ridgewood       photograph  ...       0.0
# 15757      Ridgewood       photograph  ...       0.0
# 15758      Ridgewood       photograph  ...       0.0
# 15759      Ridgewood       photograph  ...       0.0
# 15760       New York       photograph  ...       1.0
# 15761         Beacon         painting  ...       0.0
# 15762         Beacon    work-on-paper  ...       0.0
# 15763         Beacon    work-on-paper  ...       0.0
# 15764         Beacon    work-on-paper  ...       0.0
# 15765         Beacon    work-on-paper  ...       0.0
# 15766  San Francisco            print  ...      12.0
# 15767       New York            print  ...      12.0
# 15768         London            print  ...      12.0
# 15769        Toronto        sculpture  ...       0.0
# 15770          Paris      mixed-media  ...       4.0
# 15771          Paris      mixed-media  ...       4.0
# 15772          Paris      mixed-media  ...       4.0
# 15773          Paris      mixed-media  ...       4.0
#
#                                                galleries galleries_n  \
# 0                                                    n/a         0.0
# 1                                                    n/a         0.0
# 2                      [Sperone Westwater, New York, NY]         1.0
# 3                      [Sperone Westwater, New York, NY]         1.0
# 4                      [Sperone Westwater, New York, NY]         1.0
# 5                                                    n/a         0.0
# 6                                                    n/a         0.0
# 7                                                    n/a         0.0
# 8                                                    n/a         0.0
# 9            [David Risley Gallery, Copenhagen, Denmark]         1.0
# 10           [David Risley Gallery, Copenhagen, Denmark]         1.0
# 11           [David Risley Gallery, Copenhagen, Denmark]         1.0
# 12                                                   n/a         0.0
# 13                                                   n/a         0.0
# 14                                                   n/a         0.0
# 15                                                   n/a         0.0
# 16                                                   n/a         0.0
# 17                                                   n/a         0.0
# 18                                                   n/a         0.0
# 19                                                   n/a         0.0
# 20                                                   n/a         0.0
# 21                                                   n/a         0.0
# 22                                                   n/a         0.0
# 23                                                   n/a         0.0
# 24                                                   n/a         0.0
# 25                                                   n/a         0.0
# 26                                                   n/a         0.0
# 27                                                   n/a         0.0
# 28                                                   n/a         0.0
# 29                                                   n/a         0.0
# ...                                                  ...         ...
# 15744                                                n/a         0.0
# 15745                                                n/a         0.0
# 15746                                                n/a         0.0
# 15747                                                n/a         0.0
# 15748                                                n/a         0.0
# 15749                                                n/a         0.0
# 15750                                                n/a         0.0
# 15751                                                n/a         0.0
# 15752                                                n/a         0.0
# 15753                                                n/a         0.0
# 15754                                                n/a         0.0
# 15755                                                n/a         0.0
# 15756                                                n/a         0.0
# 15757                                                n/a         0.0
# 15758                                                n/a         0.0
# 15759                                                n/a         0.0
# 15760             [Kamel Mennour Gallery, Paris, France]         1.0
# 15761                                                n/a         0.0
# 15762                                                n/a         0.0
# 15763                                                n/a         0.0
# 15764                                                n/a         0.0
# 15765                                                n/a         0.0
# 15766  [Gavin Brown's enterprise, New York, NY, Sadie...         2.0
# 15767  [Gavin Brown's enterprise, New York, NY, Sadie...         2.0
# 15768  [Gavin Brown's enterprise, New York, NY, Sadie...         2.0
# 15769                                                n/a         0.0
# 15770  [Galerie Steinek, Wien, Austria, Galerie Cleme...         3.0
# 15771  [Galerie Steinek, Wien, Austria, Galerie Cleme...         3.0
# 15772  [Galerie Steinek, Wien, Austria, Galerie Cleme...         3.0
# 15773  [Galerie Steinek, Wien, Austria, Galerie Cleme...         3.0
#
#          name_last artist_death  dead  degrees_cat  galleries_cat  \
# 0      soloveychik          NaN   0.0            2            0.0
# 1      soloveychik          NaN   0.0            2            0.0
# 2         paladino          NaN   0.0            0            1.0
# 3         paladino          NaN   0.0            0            1.0
# 4         paladino          NaN   0.0            0            1.0
# 5        ryanstorm          NaN   0.0            1            0.0
# 6        ryanstorm          NaN   0.0            1            0.0
# 7        ryanstorm          NaN   0.0            1            0.0
# 8        ryanstorm          NaN   0.0            1            0.0
# 9         hylander          NaN   0.0            3            1.0
# 10        hylander          NaN   0.0            3            1.0
# 11        hylander          NaN   0.0            3            1.0
# 12             saá          NaN   0.0            2            0.0
# 13           allié          NaN   0.0            2            0.0
# 14           allié          NaN   0.0            2            0.0
# 15           allié          NaN   0.0            2            0.0
# 16           allié          NaN   0.0            2            0.0
# 17           allié          NaN   0.0            2            0.0
# 18           allié          NaN   0.0            2            0.0
# 19           allié          NaN   0.0            2            0.0
# 20           allié          NaN   0.0            2            0.0
# 21           allié          NaN   0.0            2            0.0
# 22           allié          NaN   0.0            2            0.0
# 23           allié          NaN   0.0            2            0.0
# 24           allié          NaN   0.0            2            0.0
# 25           allié          NaN   0.0            2            0.0
# 26           allié          NaN   0.0            2            0.0
# 27           allié          NaN   0.0            2            0.0
# 28           allié          NaN   0.0            2            0.0
# 29           allié          NaN   0.0            2            0.0
# ...            ...          ...   ...          ...            ...
# 15744        horan          NaN   0.0            1            0.0
# 15745        horan          NaN   0.0            1            0.0
# 15746        horan          NaN   0.0            1            0.0
# 15747        horan          NaN   0.0            1            0.0
# 15748        horan          NaN   0.0            1            0.0
# 15749        horan          NaN   0.0            1            0.0
# 15750        horan          NaN   0.0            1            0.0
# 15751        horan          NaN   0.0            1            0.0
# 15752        horan          NaN   0.0            1            0.0
# 15753        horan          NaN   0.0            1            0.0
# 15754       cabitt          NaN   0.0            1            0.0
# 15755       cabitt          NaN   0.0            1            0.0
# 15756       cabitt          NaN   0.0            1            0.0
# 15757       cabitt          NaN   0.0            1            0.0
# 15758       cabitt          NaN   0.0            1            0.0
# 15759       cabitt          NaN   0.0            1            0.0
# 15760       landau          NaN   0.0            1            1.0
# 15761        slick          NaN   0.0            2            0.0
# 15762        slick          NaN   0.0            2            0.0
# 15763        slick          NaN   0.0            2            0.0
# 15764        slick          NaN   0.0            2            0.0
# 15765        slick          NaN   0.0            2            0.0
# 15766        owens       2100.0   0.0            3            2.0
# 15767        owens       2100.0   0.0            3            2.0
# 15768        owens       2100.0   0.0            3            2.0
# 15769    littleton          NaN   0.0            0            0.0
# 15770         wolf          NaN   0.0            1            3.0
# 15771         wolf          NaN   0.0            1            3.0
# 15772         wolf          NaN   0.0            1            3.0
# 15773         wolf          NaN   0.0            1            3.0
#
#        museums_cat  log_museums_n
# 0                0           -inf
# 1                0           -inf
# 2                1       0.000000
# 3                1       0.000000
# 4                1       0.000000
# 5                0           -inf
# 6                0           -inf
# 7                0           -inf
# 8                0           -inf
# 9                2       0.693147
# 10               2       0.693147
# 11               2       0.693147
# 12               0           -inf
# 13               0           -inf
# 14               0           -inf
# 15               0           -inf
# 16               0           -inf
# 17               0           -inf
# 18               0           -inf
# 19               0           -inf
# 20               0           -inf
# 21               0           -inf
# 22               0           -inf
# 23               0           -inf
# 24               0           -inf
# 25               0           -inf
# 26               0           -inf
# 27               0           -inf
# 28               0           -inf
# 29               0           -inf
# ...            ...            ...
# 15744            0           -inf
# 15745            0           -inf
# 15746            0           -inf
# 15747            0           -inf
# 15748            0           -inf
# 15749            0           -inf
# 15750            0           -inf
# 15751            0           -inf
# 15752            0           -inf
# 15753            0           -inf
# 15754            0           -inf
# 15755            0           -inf
# 15756            0           -inf
# 15757            0           -inf
# 15758            0           -inf
# 15759            0           -inf
# 15760            1       0.000000
# 15761            0           -inf
# 15762            0           -inf
# 15763            0           -inf
# 15764            0           -inf
# 15765            0           -inf
# 15766            4       2.484907
# 15767            4       2.484907
# 15768            4       2.484907
# 15769            0           -inf
# 15770            2       1.386294
# 15771            2       1.386294
# 15772            2       1.386294
# 15773            2       1.386294
#
# [15774 rows x 72 columns]

# %%
# For first run, instantiate the image counter
imagecounter = 0

# %%
# pickle.dump(imagecounter, open('./data/artspace/images/Image counter.pickle', 'wb'))

# %% [markdown]
# Here is the main loop to download the images.

# %%
# Reload the image counter.
imagecounter = pickle.load(open('./data/artspace/images/Image counter.pickle', 'rb'))
print('Starting count for this run:', imagecounter)
print()
# Loop over each row of the dataframe.
for index, row in islice(df.iterrows(), imagecounter, None):
    # print(row['artwork_id'], row['image_url'])
    timeDelay = random.randrange(20, 30)/1000
    time.sleep(timeDelay)
    # If the artwork has an image URL, download the image.
    if row['image_url'] != 'https:None':
        img_data = requests.get(row['image_url'], headers = user_agent).content
        with open('./data/artspace/images/' + str(row['artwork_id']) + '.jpg', 'wb') as handler:
            handler.write(img_data)
    else:
        print()
        print('Missing URL:', row['artwork_id'])
        print()
    imagecounter += 1
    if imagecounter % 10 == 0:
        pickle.dump(imagecounter, open('./data/artspace/images/Image counter.pickle', 'wb'))
        print('Count:', imagecounter)
